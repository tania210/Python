# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import netCDF4 as nc

import matplotlib.pyplot as plt
import xarray as xr

# %%
df=xr.open_mfdataset("drive/MyDrive/tem.nc")
df
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 81, latitude: 81, time: 240)
# Coordinates:
#   * longitude  (longitude) float32 80.0 80.25 80.5 80.75 ... 99.5 99.75 100.0
#   * latitude   (latitude) float32 25.0 24.75 24.5 24.25 ... 5.75 5.5 5.25 5.0
#   * time       (time) datetime64[ns] 2001-01-01 2001-02-01 ... 2020-12-01
# Data variables:
#     sst        (time, latitude, longitude) float32 dask.array<chunksize=(240, 81, 81), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-03-05 14:24:02 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
df.sst[0,:,:].plot(cmap='jet')
